# %%
import pandas as pd
import seaborn as sns
from sklearn.model_selection import train_test_split
import numpy as np
import statsmodels.api as sm
from sklearn.metrics import *
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt 
from sklearn.ensemble import ExtraTreesRegressor

# %%
df=pd.read_csv('car data.csv')
df.shape
df.head()
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000    Petrol
# 1      sx4  2013           4.75           9.54       43000    Diesel
# 2     ciaz  2017           7.25           9.85        6900    Petrol
# 3  wagon r  2011           2.85           4.15        5200    Petrol
# 4    swift  2014           4.60           6.87       42450    Diesel
#
#   Seller_Type Transmission  Owner
# 0      Dealer       Manual      0
# 1      Dealer       Manual      0
# 2      Dealer       Manual      0
# 3      Dealer       Manual      0
# 4      Dealer       Manual      0

# %%
print(df['Seller_Type'].unique())
print(df['Fuel_Type'].unique())
print(df['Transmission'].unique())
print(df['Owner'].unique())
# Out:
# ['Dealer' 'Individual']
# ['Petrol' 'Diesel' 'CNG']
# ['Manual' 'Automatic']
# [0 1 3]

# %%
df.isnull().sum()
# Out:
# Car_Name         0
# Year             0
# Selling_Price    0
# Present_Price    0
# Kms_Driven       0
# Fuel_Type        0
# Seller_Type      0
# Transmission     0
# Owner            0
# dtype: int64

# %%
final_dataset=df[['Year','Selling_Price','Present_Price','Kms_Driven','Fuel_Type','Seller_Type','Transmission','Owner']]
final_dataset.head()
# Out:
#    Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type Seller_Type  \
# 0  2014           3.35           5.59       27000    Petrol      Dealer
# 1  2013           4.75           9.54       43000    Diesel      Dealer
# 2  2017           7.25           9.85        6900    Petrol      Dealer
# 3  2011           2.85           4.15        5200    Petrol      Dealer
# 4  2014           4.60           6.87       42450    Diesel      Dealer
#
#   Transmission  Owner
# 0       Manual      0
# 1       Manual      0
# 2       Manual      0
# 3       Manual      0
# 4       Manual      0

# %%
final_dataset['Current Year']=2020
final_dataset['no_year']=final_dataset['Current Year']- final_dataset['Year']
final_dataset.head()
# Out:
#    Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type Seller_Type  \
# 0  2014           3.35           5.59       27000    Petrol      Dealer
# 1  2013           4.75           9.54       43000    Diesel      Dealer
# 2  2017           7.25           9.85        6900    Petrol      Dealer
# 3  2011           2.85           4.15        5200    Petrol      Dealer
# 4  2014           4.60           6.87       42450    Diesel      Dealer
#
#   Transmission  Owner  Current Year  no_year
# 0       Manual      0          2020        6
# 1       Manual      0          2020        7
# 2       Manual      0          2020        3
# 3       Manual      0          2020        9
# 4       Manual      0          2020        6

# %%
final_dataset.drop(['Year'],axis=1,inplace=True)
final_dataset.head()
# Out:
#    Selling_Price  Present_Price  Kms_Driven Fuel_Type Seller_Type  \
# 0           3.35           5.59       27000    Petrol      Dealer
# 1           4.75           9.54       43000    Diesel      Dealer
# 2           7.25           9.85        6900    Petrol      Dealer
# 3           2.85           4.15        5200    Petrol      Dealer
# 4           4.60           6.87       42450    Diesel      Dealer
#
#   Transmission  Owner  Current Year  no_year
# 0       Manual      0          2020        6
# 1       Manual      0          2020        7
# 2       Manual      0          2020        3
# 3       Manual      0          2020        9
# 4       Manual      0          2020        6

# %%
final_dataset=pd.get_dummies(final_dataset,drop_first=True)
final_dataset.head()
# Out:
#    Selling_Price  Present_Price  Kms_Driven  Owner  Current Year  no_year  \
# 0           3.35           5.59       27000      0          2020        6
# 1           4.75           9.54       43000      0          2020        7
# 2           7.25           9.85        6900      0          2020        3
# 3           2.85           4.15        5200      0          2020        9
# 4           4.60           6.87       42450      0          2020        6
#
#    Fuel_Type_Diesel  Fuel_Type_Petrol  Seller_Type_Individual  \
# 0                 0                 1                       0
# 1                 1                 0                       0
# 2                 0                 1                       0
# 3                 0                 1                       0
# 4                 1                 0                       0
#
#    Transmission_Manual
# 0                    1
# 1                    1
# 2                    1
# 3                    1
# 4                    1

# %%
final_dataset=final_dataset.drop(['Current Year'],axis=1)

# %%
final_dataset.corr()
# Out:
#                         Selling_Price  Present_Price  Kms_Driven     Owner  \
# Selling_Price                1.000000       0.878983    0.029187 -0.088344
# Present_Price                0.878983       1.000000    0.203647  0.008057
# Kms_Driven                   0.029187       0.203647    1.000000  0.089216
# Owner                       -0.088344       0.008057    0.089216  1.000000
# no_year                     -0.236141       0.047584    0.524342  0.182104
# Fuel_Type_Diesel             0.552339       0.473306    0.172515 -0.053469
# Fuel_Type_Petrol            -0.540571      -0.465244   -0.172874  0.055687
# Seller_Type_Individual      -0.550724      -0.512030   -0.101419  0.124269
# Transmission_Manual         -0.367128      -0.348715   -0.162510 -0.050316
#
#                          no_year  Fuel_Type_Diesel  Fuel_Type_Petrol  \
# Selling_Price          -0.236141          0.552339         -0.540571
# Present_Price           0.047584          0.473306         -0.465244
# ...

# %%
X=final_dataset.iloc[:,1:]
y=final_dataset.iloc[:,0]

# %% [markdown]
# splitting

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %% [markdown]
# # Linear Regrsssion

# %%
X_train=sm.add_constant(X_train)
X_test=sm.add_constant(X_test)
model=sm.OLS(y_train,X_train)
result=model.fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:          Selling_Price   R-squared:                       0.873
# Model:                            OLS   Adj. R-squared:                  0.869
# Method:                 Least Squares   F-statistic:                     199.2
# Date:                Mon, 07 Dec 2020   Prob (F-statistic):           3.81e-99
# Time:                        19:58:18   Log-Likelihood:                -482.43
# No. Observations:                 240   AIC:                             982.9
# Df Residuals:                     231   BIC:                             1014.
# Df Model:                           8
# Covariance Type:            nonrobust
# ...
#                              coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# ...

# %%
X_train=sm.add_constant(X_train.drop(['Fuel_Type_Petrol','Owner','Kms_Driven'],axis=1))
X_test=sm.add_constant(X_test.drop(['Fuel_Type_Petrol','Owner','Kms_Driven'],axis=1))
model=sm.OLS(y_train,X_train)
result=model.fit()
result.summary()
rmse=mean_squared_error(result.predict(X_test),y_test)
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:          Selling_Price   R-squared:                       0.870
# Model:                            OLS   Adj. R-squared:                  0.867
# Method:                 Least Squares   F-statistic:                     312.4
# Date:                Mon, 07 Dec 2020   Prob (F-statistic):          2.18e-101
# Time:                        20:01:02   Log-Likelihood:                -485.89
# No. Observations:                 240   AIC:                             983.8
# Df Residuals:                     234   BIC:                             1005.
# Df Model:                           5
# Covariance Type:            nonrobust
# ...
#                              coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# ...

# %%
print("RSME value for linear regression",rmse)
# Out:
# RSME value for linear regression 1.0789016159537568

# %%
print('MAE value for linear regression:',mean_absolute_error(y_test, result.predict(X_test)))
# Out:
# MAE value for linear regression: 0.9839383507134961

# %% [markdown]
# # Random forest regressor

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)
#X_train=X_train.drop(['Owner'],axis=1)
#X_test=X_test.drop(['Owner'],axis=1)

# %%
regressor=RandomForestRegressor()

# %%
n_estimators = [int(x) for x in np.linspace(start = 100, stop = 1200, num = 12)]
print(n_estimators)
# Out:
# [100, 200, 300, 400, 500, 600, 700, 800, 900, 1000, 1100, 1200]

# %%
from sklearn.model_selection import RandomizedSearchCV

# %%
#Randomized Search CV

# Number of trees in random forest
n_estimators = [int(x) for x in np.linspace(start = 100, stop = 1200, num = 12)]
# Number of features to consider at every split
max_features = ['auto', 'sqrt']
# Maximum number of levels in tree
max_depth = [int(x) for x in np.linspace(5, 30, num = 6)]
# max_depth.append(None)
# Minimum number of samples required to split a node
min_samples_split = [2, 5, 10, 15, 100]
# Minimum number of samples required at each leaf node
min_samples_leaf = [1, 2, 5, 10]

# %%
random_grid = {'n_estimators': n_estimators,
               'max_features': max_features,
               'max_depth': max_depth,
               'min_samples_split': min_samples_split,
               'min_samples_leaf': min_samples_leaf}

print(random_grid)
# Out:
# {'n_estimators': [100, 200, 300, 400, 500, 600, 700, 800, 900, 1000, 1100, 1200], 'max_features': ['auto', 'sqrt'], 'max_depth': [5, 10, 15, 20, 25, 30], 'min_samples_split': [2, 5, 10, 15, 100], 'min_samples_leaf': [1, 2, 5, 10]}

# %%
rf = RandomForestRegressor()

# %%
rf_random = RandomizedSearchCV(estimator = rf, param_distributions = random_grid,scoring='neg_mean_squared_error', n_iter = 10, cv = 3, verbose=2, random_state=42, n_jobs = 1)

# %%
rf_random.fit(X_train,y_train)
# Out:
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV] n_estimators=900, min_samples_split=5, min_samples_leaf=5, max_features=sqrt, max_depth=10
# [CV]  n_estimators=900, min_samples_split=5, min_samples_leaf=5, max_features=sqrt, max_depth=10, total=   5.5s
# [CV] n_estimators=900, min_samples_split=5, min_samples_leaf=5, max_features=sqrt, max_depth=10
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    6.0s remaining:    0.0s
# [CV]  n_estimators=900, min_samples_split=5, min_samples_leaf=5, max_features=sqrt, max_depth=10, total=   2.1s
# [CV] n_estimators=900, min_samples_split=5, min_samples_leaf=5, max_features=sqrt, max_depth=10
# [CV]  n_estimators=900, min_samples_split=5, min_samples_leaf=5, max_features=sqrt, max_depth=10, total=   2.2s
# [CV] n_estimators=1100, min_samples_split=10, min_samples_leaf=2, max_features=sqrt, max_depth=15
# ...

# %%
rf_random.best_params_
# Out:
# {'n_estimators': 1000,
#  'min_samples_split': 2,
#  'min_samples_leaf': 1,
#  'max_features': 'sqrt',
#  'max_depth': 25}

# %%
predictions=rf_random.predict(X_test)

# %%
from sklearn.metrics import r2_score
test_score=r2_score(y_test,predictions)
print('MAE:',mean_absolute_error(y_test, predictions))
print('MSE:',mean_squared_error(y_test, predictions))
print('RMSE:', np.sqrt(mean_squared_error(y_test, predictions)))
print('r2 value is ',test_score)
# Out:
# MAE: 0.599800163934423
# MSE: 1.5479912383491794
# RMSE: 1.2441829601586656
# r2 value is  0.9387596736558348

# %%
import pickle
# open a file, where you ant to store the data
file = open('random_forest_regression_modell.pkl', 'wb')

# dump information to that file
pickle.dump(rf_random, file)

# %%
from sklearn.metrics import r2_score

# %%
test_score=r2_score(y_test,predictions)

# %%
test_score
# Out:
# 0.9387596736558348

# %%
X_train
# Out:
#      Present_Price  Kms_Driven  Owner  no_year  Fuel_Type_Diesel  \
# 74            8.93       83000      0        6                 1
# 239           4.43       23709      0        8                 0
# 64           36.23        6000      0        3                 1
# 294           6.80       33019      0        6                 0
# 286           7.90       28569      0        4                 0
# ..             ...         ...    ...      ...               ...
# 251           9.90       56701      0        7                 0
# 192           0.75       49000      1       13                 0
# 117           1.90       14000      0        5                 0
# 47            4.15       65000      0       14                 0
# 172           0.64       13700      0        6                 0
#
#      Fuel_Type_Petrol  Seller_Type_Individual  Transmission_Manual
# 74                  0                       0                    1
# ...
